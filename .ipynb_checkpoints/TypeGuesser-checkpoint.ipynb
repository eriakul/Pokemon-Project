# %%
from csv import reader
import pandas as pd


def parseCSV(filename="dataset\pokemon.csv"):  #return (fields, rows)
    return pd.read_csv(filename)

# %%
df = parseCSV()

# %%
import cv2
import numpy as np
from glob import glob
import pandas as pd
from os import path
# %matplotlib inline
import matplotlib.pyplot as plt

# df.index = df['Name']
# images = []
# has_cactus = []
# for file in sorted(glob('dataset/images/*.jpg')):
#     im = cv2.imread(file)
#     im = cv2.cvtColor(im, cv2.COLOR_BGR2RGB)
#     images.append(im)

# images = np.array(images)
# y = np.array(has_cactus)

# fig, ax = plt.subplots(10, 10, figsize=(20, 20))

# for i in range(10):
#     ax = plt.subplot(10, 10, i+1)
#     ax.imshow(images[i, :, :, :].squeeze(), interpolation='none')
#     ax.set_axis_off()
# plt.show()

#df.shape = (809, 3)

def create_image_matrix(df):
    images = []
    for pokemonName in df["Name"]:
        file = 'dataset/images/{}.jpg'.format(pokemonName)
        im = cv2.imread(file, 1) #1 for color image
        images.append(im)
        
create_image_matrix(df)

# %%
print(images)
# Out:
# [[[[255 255 255]
#    [255 255 255]
#    [255 255 255]
#    ...,
#    [255 255 255]
#    [255 255 255]
#    [255 255 255]]
#
#   [[255 255 255]
#    [255 255 255]
#    [255 255 255]
#    ...,
#    [255 255 255]
#    [255 255 255]
#    [255 255 255]]
#
#   [[255 255 255]
#    [255 255 255]
#    [255 255 255]
#    ...,
#    [255 255 255]
#    [255 255 255]
#    [255 255 255]]
#
#   ...,
#   [[255 255 255]
#    [255 255 255]
#    [255 255 255]
#    ...,
#    [255 255 255]
#    [255 255 255]
#    [255 255 255]]
#
#   [[255 255 255]
#    [255 255 255]
#    [255 255 255]
#    ...,
#    [255 255 255]
#    [255 255 255]
#    [255 255 255]]
#
#   [[255 255 255]
#    [255 255 255]
#    [255 255 255]
#    ...,
#    [255 255 255]
#    [255 255 255]
#    [255 255 255]]]
#
#
#  [[[255 255 255]
#    [255 255 255]
#    [255 255 255]
#    ...,
#    [255 255 255]
#    [255 255 255]
#    [255 255 255]]
#
#   [[255 255 255]
#    [255 255 255]
#    [255 255 255]
#    ...,
#    [255 255 255]
# ...
